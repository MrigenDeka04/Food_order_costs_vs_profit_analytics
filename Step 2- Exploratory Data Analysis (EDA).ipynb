# %% [markdown]
# #  Exploratory Data Analysis (EDA)

# %%
# Import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv("food_orders_new_delhi (1).csv")

sns.set(style="whitegrid")

# Orders by Restaurant
top_restaurants = df['Restaurant ID'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_restaurants.values, y=top_restaurants.index)
plt.title("Top 10 Restaurants by Number of Orders")
plt.xlabel("Order Count")
plt.ylabel("Restaurant ID")
plt.show()

# %% [markdown]
# ### Payment Method Distribution

# %%
df['Payment Method'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(6, 6), startangle=140)
plt.title("Payment Method Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Convert dates

# %%
df['Order Date and Time'] = pd.to_datetime(df['Order Date and Time'])
df['Delivery Date and Time'] = pd.to_datetime(df['Delivery Date and Time'])

# %% [markdown]
# ### Order Trend Over Time

# %%
df['Order Date'] = df['Order Date and Time'].dt.date
daily_orders = df.groupby('Order Date').size().reset_index(name='Order Count')
plt.figure(figsize=(14, 6))
sns.lineplot(x='Order Date', y='Order Count', data=daily_orders, marker='o')
plt.title("Order Trend Over Time")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
